# %% [markdown]
# <a href="https://colab.research.google.com/github/Imsachin010/AI-ML-Projects/blob/main/Image_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision transformers pillow

# %%
import torch
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
from IPython.display import display

# %%
def load_image(image_path):
    """Loads an image from the file system."""
    image = Image.open('/content/drive/MyDrive/Image conversational Chat bot/person with car.jpg')
    return image

# %%
# def get_image_context(image):
#     """Generates context text for a given image using CLIP."""
#     # Load the pre-trained CLIP model and processor
#     model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
#     processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

#     # Prepare the image for the model
#     inputs = processor(images=image, return_tensors="pt")

#     # Forward pass to get the features
#     outputs = model.get_image_features(**inputs)

#     # Generate possible context (prompts) to match with the image
#     possible_contexts = ["a photograph of a cat", "a beautiful landscape",
#                          "a person working on a laptop", "a group of people",
#                          "a close-up of food", "an outdoor scene"]

#     # Tokenize possible contexts and get their features
#     text_inputs = processor(text=possible_contexts, return_tensors="pt", padding=True)
#     text_features = model.get_text_features(**text_inputs)

#     # Compute similarity between image and each context
#     similarities = torch.matmul(outputs, text_features.T)

#     # Get the best context
#     best_match_idx = torch.argmax(similarities, dim=1).item()

#     return possible_contexts[best_match_idx]

# %%
def generate_image_caption(image):
    """Generates a caption for a given image using BLIP."""
    # Load the pre-trained BLIP model and processor
    processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
    model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

    # Prepare the image for the model
    inputs = processor(images=image, return_tensors="pt")

    # Generate caption
    outputs = model.generate(**inputs)
    caption = processor.decode(outputs[0], skip_special_tokens=True)

    return caption

# %%
image_path = "sample.jpg"
image = load_image(image_path)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
context = get_image_context(image)
print(f"Image Context: {context}")
# Out:
# Image Context: a beautiful landscape
